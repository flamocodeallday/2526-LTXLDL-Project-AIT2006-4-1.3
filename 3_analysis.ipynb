# %%
import pandas as pd
import sys
import os

# Add project root to Python path to allow module imports
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from src.utils.kpi import kpi
from src.utils.data_visualization import data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 10
#       7 if project_root not in sys.path:
#       8     sys.path.append(project_root)
# ---> 10 from src.utils.kpi import kpi
#      11 from src.utils.data_visualization import data
#
# ImportError: cannot import name 'kpi' from 'src.utils.kpi' (d:\Python\2526-LTXLDL-Project-AIT2006-4-1.3\src\utils\kpi.py)

# %%
df1 = pd.read_parquet("../processed/yellow_tripdata_2021-01_cleaned.parquet")
df1_kpi = kpi(df1)
print(df1_kpi['daily'].head())

# %%
df1_viz = data(df1_kpi)
