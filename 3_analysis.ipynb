# %%
import pandas as pd
import sys
import os

# Add project root to Python path to allow module imports
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from src.utils.kpi import kpi
from src.utils.data_visualization import data

# %%
df1 = pd.read_parquet("../processed/yellow_tripdata_2021-01_cleaned.parquet")
df1_kpi = kpi(df1)
print(df1_kpi['daily'].head())
# Out:
# d:\Python\2526-LTXLDL-Project-AIT2006-4-1.3\src\utils\kpi.py:58: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_monthly = df_calc.groupby(pd.Grouper(key=col_date, freq='M')).agg(agg_rules)
#   tpep_pickup_datetime  duration_p50  duration_p95  speed_p50
# 0           2021-01-01           9.0          30.0      14.58
# 1           2021-01-02          10.0          32.0      12.69
# 2           2021-01-03           9.0          32.0      14.37
# 3           2021-01-04           9.0          32.0      12.29
# 4           2021-01-05           9.0          31.0      11.81

# %%
df1_viz = data(df1)
# Out:
# d:\Python\2526-LTXLDL-Project-AIT2006-4-1.3\src\utils\data_visualization.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=weekday_counts.index, y=weekday_counts.values, palette="viridis", order=day_map)
# d:\Python\2526-LTXLDL-Project-AIT2006-4-1.3\src\utils\data_visualization.py:57: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=trip_count_per_passenger_count.index, y=trip_count_per_passenger_count.values, palette="viridis")
# d:\Python\2526-LTXLDL-Project-AIT2006-4-1.3\src\utils\data_visualization.py:67: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=LocationID_counts.values, y=LocationID_counts.index, palette="viridis", orient='h', order=LocationID_counts.index)
# d:\Python\2526-LTXLDL-Project-AIT2006-4-1.3\src\utils\data_visualization.py:105: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=trip_count_per_hour.index, y=trip_count_per_hour.values, palette="viridis")
